# %% [markdown]
# This short project is an example for webscraping.
# For this project, https://elibrary.judiciary.gov.ph was used to get all the jurisprudence posted in the site.

# %%
import requests
from bs4 import BeautifulSoup
import re
import json
import random

# Base URL
elibrary_url = 'https://elibrary.judiciary.gov.ph/'

# Regular expression patterns
year_pattern = r'/(\d{4})/'
month_pattern = r'(Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)'


def extract_years_months(url):
    """
    Extracts all links with available data
    """
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    container = soup.find('div', id='container_date')
    # Extract year and month
    year_months_list = [
        (
            a['href'],
            re.search(year_pattern, a['href']).group(1) if re.search(year_pattern, a['href']) else None,
            re.search(month_pattern, a['href'], re.IGNORECASE).group(0) if re.search(month_pattern, a['href'], re.IGNORECASE) else None
        )
        for a in container.find_all('a') if 'href' in a.attrs
    ]
    return year_months_list


def extract_text_links(url):
    """
    Function to extract texts from a given elibrary URL
    """
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    container = soup.find('div', id='container_title')
    decision_links = container.find_all('a')
    # print("Count decisions: ", len(decision_links))
    return [(a['href'], a.text) for a in decision_links]

# Function to extract resolution text
def extract_text_data(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    container = soup.find('div', class_='single_content')

    if container:
        resolution_text = container.get_text()

        # Remove the first 6 lines (For printing purposes)
        lines = resolution_text.split('\n')
        filtered_lines = lines[6:]

        # Join the remaining lines back into a single string
        filtered_text = '\n'.join(filtered_lines)
        return filtered_text
    else:
        return ""


def save_text_to_files(text, url, file_base_name):
    """
    Function to save text to json file
    """
    file_name = f"{file_base_name}.json"
    data = {
        'text': text,
        'url': url
    }
    with open(file_name, 'w', encoding='utf-8') as output_file:
        json.dump(data, output_file, ensure_ascii=False, indent=4)

# %%
# DEPRECATED data extraction technique
# import requests
# from bs4 import BeautifulSoup
# import re
# import time
# from transformers import GPT2Tokenizer
# import json

# # Initialize the tokenizer
# tokenizer = GPT2Tokenizer.from_pretrained("gpt2")

# # Base URL
# elibrary_url = 'https://elibrary.judiciary.gov.ph/'
# max_tokens = 7800  # Assuming a token limit, adjust based on actual requirements

# # Regular expression patterns
# year_pattern = r'/(\d{4})/'
# month_pattern = r'(Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)'

# # Function to extract years and months
# def extract_years_months(url):
#     response = requests.get(url)
#     soup = BeautifulSoup(response.content, 'html.parser')
#     container = soup.find('div', id='container_date')
#     # Extract year and month
#     year_months_list = [
#         (
#             a['href'],
#             re.search(year_pattern, a['href']).group(1) if re.search(year_pattern, a['href']) else None,
#             re.search(month_pattern, a['href'], re.IGNORECASE).group(0) if re.search(month_pattern, a['href'], re.IGNORECASE) else None
#         )
#         for a in container.find_all('a') if 'href' in a.attrs
#     ]
#     return year_months_list

# # Function to extract decision links for a specific month
# def extract_decision_links(url):
#     response = requests.get(url)
#     soup = BeautifulSoup(response.content, 'html.parser')
#     container = soup.find('div', id='container_title')
#     decision_links = container.find_all('a')
#     # print("Count decisions: ", len(decision_links))
#     return [(a['href'], a.text) for a in decision_links]

# # Function to extract resolution text
# def extract_resolution_text(url):
#     response = requests.get(url)
#     soup = BeautifulSoup(response.content, 'html.parser')
#     container = soup.find('div', class_='single_content')
    
#     if container:
#         resolution_text = container.get_text()
        
#         # Remove the first 6 lines (For printing purposes)
#         lines = resolution_text.split('\n')
#         filtered_lines = lines[6:]

#         # Join the remaining lines back into a single string
#         filtered_text = '\n'.join(filtered_lines)
#         return filtered_text
#     else:
#         return ""

# # Function to save text to files
# def save_text_to_files(text, url, file_base_name):
#     tokens = tokenizer.encode(text)
#     part = 1
#     while tokens:
#         chunk = tokens[:max_tokens]
#         tokens = tokens[max_tokens:]
#         chunk_text = tokenizer.decode(chunk)
#         file_name = f"{file_base_name}_Part{part}.json"
#         data = {
#             'text': chunk_text,
#             'url': url
#         }
#         with open(file_name, 'w', encoding='utf-8') as output_file:
#             json.dump(data, output_file, ensure_ascii=False, indent=4)
#         part += 1

# %%
year_month_urls = extract_years_months(elibrary_url)
len(year_month_urls)
# Out:
# 333

# %%
def sanitize_filename(filename):
    # Replace invalid characters with an underscore
    sanitized = re.sub(r'[<>:"/\\|?*]', '_', filename)
    return sanitized

# %%
# Starting point for scraping (adjust as needed)
start_year = 2015
start_month = 'Jan'
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
# Scrape all text data for each outer link
# year_month_urls is the outer URL
for ym_link, year, month in year_month_urls:
    # Check if we need to skip this year and month
    if int(year) > start_year or (int(year) == start_year and months.index(month) < months.index(start_month)):
        continue
    print(f"---------- {year}-{month} ----------")
    text_links = extract_text_links(ym_link)
    print("Count text links: ", len(text_links))
    # Iterate through each inner link to get the text
    # text_links is the inner URL

    # Shuffle and select 5 random text links, if available
    random.shuffle(text_links)
    selected_text_links = text_links[:1]
    
    for i, (link_to_text, anchor) in enumerate(selected_text_links):
        match = re.match(r'^(.*?)\n', anchor)
        if match:
            title = sanitize_filename(match.group(1))
            print(title)

        text_data = extract_text_data(link_to_text)
        if text_data:
            case_number = title[:100]
            file_base_name = f'{year}_{month}_{case_number}'
            save_text_to_files(text_data, link_to_text, file_base_name)
# Out:
# ---------- 2015-Jan ----------
# Count text links:  95
# G.R. No. 156995
# ---------- 2015-Feb ----------
# Count text links:  105
# G.R. No. 171672
# ---------- 2015-Mar ----------
# Count text links:  94
# G.R. No. 179047
# ---------- 2015-Apr ----------
# Count text links:  70
# G.R. No. 171601
# ---------- 2015-Jun ----------
# Count text links:  109
# A.C. No. 10138 (Formerly CBD Case No. 06-1876)
# ---------- 2015-Jul ----------
# Count text links:  138
# G.R. No. 205228
# ---------- 2015-Aug ----------
# Count text links:  101
# A.C. No. 6738
# ---------- 2015-Sep ----------
# Count text links:  98
# G.R. No. 205379
# ---------- 2015-Oct ----------
# Count text links:  57
# G.R. No. 181284
# ---------- 2015-Nov ----------
# Count text links:  61
# A.C. No. 8507
# ---------- 2015-Dec ----------
# Count text links:  61
# G.R. No. 159979
# ---------- 2014-Jan ----------
# Count text links:  79
# A.C. No. 8644 [Formerly CBD Case No. 11-2908]
# ---------- 2014-Feb ----------
# Count text links:  75
# G.R. No. 179625
# ---------- 2014-Mar ----------
# Count text links:  99
# A.M. No. P-12-3070 [Formerly A.M. OCA IPI No. 10-3327-P]
# ---------- 2014-Apr ----------
# Count text links:  84
# G.R. No. 180016
# ---------- 2014-May ----------
# Count text links:  1
# G.R. No. 196735
# ---------- 2014-Jun ----------
# Count text links:  136
# G.R. No. 179962
# ---------- 2014-Jul ----------
# Count text links:  118
# G.R. No. 203288
# ---------- 2014-Aug ----------
# Count text links:  67
# G.R. No. 195432
# ---------- 2014-Sep ----------
# Count text links:  115
# G.R. No. 198656
# ---------- 2014-Oct ----------
# Count text links:  77
# A.M. No. P-14-3278 [Formerly A.M. OCA IPI No. 09-3222-P]
# ---------- 2014-Nov ----------
# Count text links:  122
# G.R. No. 183872
# ---------- 2014-Dec ----------
# Count text links:  55
# G.R. No. 187589
# ---------- 2013-Jan ----------
# Count text links:  87
# G.R. No. 174191
# ---------- 2013-Feb ----------
# Count text links:  91
# G.R. No. 168703
# ---------- 2013-Mar ----------
# Count text links:  76
# G.R. No. 203833
# ---------- 2013-Apr ----------
# Count text links:  90
# G.R. Nos. 186739-960
# ---------- 2013-Jun ----------
# Count text links:  130
# G.R. No. 186137
# ---------- 2013-Jul ----------
# Count text links:  129
# G.R. No. 181444
# ---------- 2013-Aug ----------
# Count text links:  53
# G.R. No. 188595
# ---------- 2013-Sep ----------
# Count text links:  73
# G.R. No. 197522
# ---------- 2013-Oct ----------
# Count text links:  84
# G.R. No. 181508
# ---------- 2013-Nov ----------
# Count text links:  78
# G.R. No. 181473
# ---------- 2013-Dec ----------
# Count text links:  66
# G.R. No. 182356
# ---------- 2012-Jan ----------
# Count text links:  68
# G.R. No. 164197
# ---------- 2012-Feb ----------
# Count text links:  126
# G.R. No. 183622
# ---------- 2012-Mar ----------
# Count text links:  67
# G.R. No. 178367
# ---------- 2012-Apr ----------
# Count text links:  94
# A.C. No. 7481
# ---------- 2012-Jun ----------
# Count text links:  135
# G.R. No. 170509
# ---------- 2012-Jul ----------
# Count text links:  104
# A.C. No. 6910
# ---------- 2012-Aug ----------
# Count text links:  74
# G.R. No. 195243
# ---------- 2012-Sep ----------
# Count text links:  82
# G.R. No. 192117
# ---------- 2012-Oct ----------
# Count text links:  73
# G.R. No. 192650
# ---------- 2012-Nov ----------
# Count text links:  85
# G.R. No. 184056
# ---------- 2012-Dec ----------
# Count text links:  50
# G.R. No. 188107
# ---------- 2011-Jan ----------
# Count text links:  113
# G.R. No. 160923
# ---------- 2011-Feb ----------
# Count text links:  116
# G.R. Nos. 174730-37
# ---------- 2011-Mar ----------
# Count text links:  117
# G.R. No. 178454
# ---------- 2011-Apr ----------
# Count text links:  68
# G.R. No. 169292
# ---------- 2011-May ----------
# Count text links:  39
# G.R. No. 174660
# ---------- 2011-Jun ----------
# Count text links:  123
# G.R. No. 182917
# ---------- 2011-Jul ----------
# Count text links:  70
# G.R. No. 184253
# ---------- 2011-Aug ----------
# Count text links:  81
# G.R. No. 166970
# ---------- 2011-Sep ----------
# Count text links:  77
# G.R. No. 164181
# ---------- 2011-Oct ----------
# Count text links:  74
# G.R. No. 194076
# ---------- 2011-Nov ----------
# Count text links:  65
# G.R. No. 182412
# ---------- 2011-Dec ----------
# Count text links:  43
# G.R. No. 152375
# ---------- 2010-Jan ----------
# Count text links:  65
# G.R. No. 157659
# ---------- 2010-Feb ----------
# Count text links:  134
# G.R. No. 183063
# ---------- 2010-Mar ----------
# Count text links:  152
# G.R. No. 165951
# ---------- 2010-Apr ----------
# Count text links:  99
# G.R. No. 185849
# ---------- 2010-May ----------
# Count text links:  31
# G.R. No. 180062
# ---------- 2010-Jun ----------
# Count text links:  87
# G.R. No. 187972
# ---------- 2010-Jul ----------
# Count text links:  150
# G.R. No. 186466
# ---------- 2010-Aug ----------
# Count text links:  155
# G.R. No. 187104
# ---------- 2010-Sep ----------
# Count text links:  99
# G.R. No. 182707
# ---------- 2010-Oct ----------
# Count text links:  112
# G.R. No. 161934
# ---------- 2010-Nov ----------
# Count text links:  91
# G.R. No. 166566
# ---------- 2010-Dec ----------
# Count text links:  95
# G.R. No. 188901
# ---------- 2009-Jan ----------
# Count text links:  99
# G.R. No. 161237
# ---------- 2009-Feb ----------
# Count text links:  113
# G.R. No. 159310
# ---------- 2009-Mar ----------
# Count text links:  109
# G.R. No. 180188
# ---------- 2009-Apr ----------
# Count text links:  163
# G.R. No. 152131
# ---------- 2009-May ----------
# Count text links:  42
# G.R. No. 182418
# ---------- 2009-Jun ----------
# Count text links:  151
# G.R. No. 185140
# ---------- 2009-Jul ----------
# Count text links:  166
# G.R. No. 166640
# ---------- 2009-Aug ----------
# Count text links:  113
# G.R. No. 160610
# ---------- 2009-Sep ----------
# Count text links:  149
# G.R. No. 184225
# ---------- 2009-Oct ----------
# Count text links:  152
# G.R. No. 184702
# ---------- 2009-Nov ----------
# Count text links:  62
# G.R. No. 186616
# ---------- 2009-Dec ----------
# Count text links:  110
# G.R. No. 179952
# ---------- 2008-Jan ----------
# Count text links:  76
# A.M. No. 06-9-545-RTC
# ---------- 2008-Feb ----------
# Count text links:  165
# A.M. No. P-07-2398 (Formerly OCA IPI No. 03-1621-P)
# ---------- 2008-Mar ----------
# Count text links:  119
# G.R. No. 169914
# ---------- 2008-Apr ----------
# Count text links:  128
# G.R. No. 168999
# ---------- 2008-May ----------
# Count text links:  15
# G.R. No. 161455
# ---------- 2008-Jun ----------
# Count text links:  140
# G.R. No. 159934
# ---------- 2008-Jul ----------
# Count text links:  171
# G.R. No. 178907
# ---------- 2008-Aug ----------
# Count text links:  134
# G.R. No. 178067
# ---------- 2008-Sep ----------
# Count text links:  137
# G.R. No. 153077
# ---------- 2008-Oct ----------
# Count text links:  135
# A.M. No. RTJ-07-2074 [Formerly A.M. No. 07-5-18-SC]
# ---------- 2008-Nov ----------
# Count text links:  98
# A.M. No. 2008-13-SC
# ---------- 2008-Dec ----------
# Count text links:  124
# G.R. No. 179813
# ---------- 2007-Jan ----------
# Count text links:  98
# G.R. NO. 115880
# ---------- 2007-Feb ----------
# Count text links:  155
# G.R. NO. 173979
# ---------- 2007-Mar ----------
# Count text links:  133
# G.R. NO. 173243
# ---------- 2007-Apr ----------
# Count text links:  146
# G.R. NO. 169353
# ---------- 2007-May ----------
# Count text links:  23
# G.R. No. 169413
# ---------- 2007-Jun ----------
# Count text links:  128
# G.R. No. 171764
# ---------- 2007-Jul ----------
# Count text links:  147
# G.R. NO. 169869
# ---------- 2007-Aug ----------
# Count text links:  167
# G.R. No. 165955
# ---------- 2007-Sep ----------
# Count text links:  133
# G.R. No. 146221
# ---------- 2007-Oct ----------
# Count text links:  131
# G.R. No. 110478[1]
# ---------- 2007-Nov ----------
# Count text links:  84
# G.R. No. 176667
# ---------- 2007-Dec ----------
# Count text links:  79
# G.R. NO. 159666
# ---------- 2006-Jan ----------
# Count text links:  117
# ADM. CASE NO. 5649
# ---------- 2006-Feb ----------
# Count text links:  105
# G.R. NO. 147989
# ---------- 2006-Mar ----------
# Count text links:  127
# G.R. NO. 162015
# ---------- 2006-Apr ----------
# Count text links:  76
# G.R. NO. 167959
# ---------- 2006-May ----------
# Count text links:  60
# G.R. NO. 161654
# ---------- 2006-Jun ----------
# Count text links:  179
# G.R. NO. 167806
# ---------- 2006-Jul ----------
# Count text links:  167
# A.M. NO. RTJ-06-2005
# ---------- 2006-Aug ----------
# Count text links:  173
# G.R. NO. 149019
# ---------- 2006-Sep ----------
# Count text links:  143
# G.R. NO. 143530
# ---------- 2006-Oct ----------
# Count text links:  106
# G.R. NO. 162442
# ---------- 2006-Nov ----------
# Count text links:  121
# G.R. NO. 159734
# ---------- 2006-Dec ----------
# Count text links:  84
# G.R. NO. 171017
# ---------- 2005-Jan ----------
# Count text links:  121
# G.R. NO. 152238
# ---------- 2005-Feb ----------
# Count text links:  115
# A.M. NO. P-03-1708 (FORMERLY A.M. NO. 02-10-1275-METC)
# ---------- 2005-Mar ----------
# Count text links:  124
# G.R. NO. 160368
# ---------- 2005-Apr ----------
# Count text links:  121
# A.M. NO. P-05-1993 (OCA I.P.I. NO. 04-1971-P)
# ---------- 2005-May ----------
# Count text links:  67
# G.R. NO. 156117
# ---------- 2005-Jun ----------
# Count text links:  166
# A.M. No. RTJ-03-1804 (Formerly OCA IPI No. 03-1850-RTJ)
# ---------- 2005-Jul ----------
# Count text links:  118
# G.R. No. 151452
# ---------- 2005-Aug ----------
# Count text links:  145
# G.R. NOS. 160929-31
# ---------- 2005-Sep ----------
# Count text links:  135
# G.R. NO. 142022
# ---------- 2005-Oct ----------
# Count text links:  123
# G.R. NO. 154126
# ---------- 2005-Nov ----------
# Count text links:  118
# G.R. No. 166645
# ---------- 2005-Dec ----------
# Count text links:  104
# A.M. NO. 04-9-512-RTC
# ---------- 2004-Jan ----------
# Count text links:  122
# A.M. No. MTJ-04-1525 (Formerly A.M. OCA IPI No. 00-927-MTJ)
# ---------- 2004-Feb ----------
# Count text links:  127
# G.R. No. 146111
# ---------- 2004-Mar ----------
# Count text links:  145
# G.R. Nos. 132127-29
# ---------- 2004-Apr ----------
# Count text links:  77
# G.R. No. 149253
# ---------- 2004-May ----------
# Count text links:  116
# G.R. No. 151251
# ---------- 2004-Jun ----------
# Count text links:  132
# G.R. No. 148737
# ---------- 2004-Jul ----------
# Count text links:  136
# G.R. No. 146621
# ---------- 2004-Aug ----------
# Count text links:  96
# G.R. No. 142668
# ---------- 2004-Sep ----------
# Count text links:  103
# G.R. No. 155043
# ---------- 2004-Oct ----------
# Count text links:  84
# G.R. No. 130003
# ---------- 2004-Nov ----------
# Count text links:  125
# G.R. NO. 148739
# ---------- 2004-Dec ----------
# Count text links:  73
# A.M. No. MTJ-04-1529 [Formerly OCA IPI No. 03-1406-MTJ]
# ---------- 2003-Jan ----------
# Count text links:  98
# G.R. No. 136112
# ---------- 2003-Feb ----------
# Count text links:  116
# G.R. No. 140853
# ---------- 2003-Mar ----------
# Count text links:  86
# G.R. No. 131636
# ---------- 2003-Apr ----------
# Count text links:  132
# G.R. No. 128512
# ---------- 2003-May ----------
# Count text links:  26
# G.R. No. 139879
# ---------- 2003-Jun ----------
# Count text links:  108
# G.R. No. 150611
# ---------- 2003-Jul ----------
# Count text links:  116
# G.R. No. 136741
# ---------- 2003-Aug ----------
# Count text links:  116
# G.R. No. 148848
# ---------- 2003-Sep ----------
# Count text links:  117
# G.R. Nos. 146786-88
# ---------- 2003-Oct ----------
# Count text links:  116
# A.M. No. P-02-1550
# ---------- 2003-Nov ----------
# Count text links:  81
# A.M. No. RTJ-03-1813
# ---------- 2003-Dec ----------
# Count text links:  82
# G.R. No. 145417
# ---------- 2002-Jan ----------
# Count text links:  147
# G.R. No. 145973
# ---------- 2002-Feb ----------
# Count text links:  121
# G.R. No. 144476
# ---------- 2002-Mar ----------
# Count text links:  81
# G.R. No. 136145
# ---------- 2002-Apr ----------
# Count text links:  105
# G.R. No. 142936
# ---------- 2002-May ----------
# Count text links:  67
# G.R. No. 138614
# ---------- 2002-Jun ----------
# Count text links:  38
# G.R. No. 146277
# ---------- 2002-Jul ----------
# Count text links:  124
# G.R. No. 138401
# ---------- 2002-Aug ----------
# Count text links:  118
# G.R. No. 145503
# ---------- 2002-Sep ----------
# Count text links:  109
# A.M. NO. P-00-1364
# ---------- 2002-Oct ----------
# Count text links:  63
# G.R. Nos. 130078-82
# ---------- 2002-Nov ----------
# Count text links:  99
# G.R. No. 143868
# ---------- 2002-Dec ----------
# Count text links:  78
# G.R. No. 149906
# ---------- 2001-Jan ----------
# Count text links:  109
# G.R. No. 139471
# ---------- 2001-Feb ----------
# Count text links:  130
# G.R. No. 141244
# ---------- 2001-Mar ----------
# Count text links:  143
# G.R. No. 139300
# ---------- 2001-Apr ----------
# Count text links:  88
# G.R. No. 132170
# ---------- 2001-May ----------
# Count text links:  54
# G.R. No. 130627 and Nos. 139477-78
# ---------- 2001-Jun ----------
# Count text links:  129
# A.M. No. 00-10-230-MTCC
# ---------- 2001-Jul ----------
# Count text links:  94
# G.R. No. 126166
# ---------- 2001-Aug ----------
# Count text links:  135
# A.M. No. P-00-1415-MeTC
# ---------- 2001-Sep ----------
# Count text links:  127
# G.R. No. 111584
# ---------- 2001-Oct ----------
# Count text links:  125
# G.R. No. 137599
# ---------- 2001-Nov ----------
# Count text links:  127
# G.R. No. 141881
# ---------- 2001-Dec ----------
# Count text links:  99
# G.R. No. 134741
# ---------- 2000-Jan ----------
# Count text links:  139
# G.R. No. 137560
# ---------- 2000-Feb ----------
# Count text links:  165
# A.M. No. 96-12-429-RTC
# ---------- 2000-Mar ----------
# Count text links:  156
# G.R. No. 100152
# ---------- 2000-Apr ----------
# Count text links:  91
# G.R. No. 125292
# ---------- 2000-May ----------
# Count text links:  90
# G.R. No. 139801
# ---------- 2000-Jun ----------
# Count text links:  116
# G.R. No. 117356
# ---------- 2000-Jul ----------
# Count text links:  110
# G.R. No. 135406
# ---------- 2000-Aug ----------
# Count text links:  149
# G.R. No. 122089
# ---------- 2000-Sep ----------
# Count text links:  110
# G.R. No. 115054-66
# ---------- 2000-Oct ----------
# Count text links:  164
# G.R. No. 128559
# ---------- 2000-Nov ----------
# Count text links:  134
# G.R. No. 128819
# ---------- 2000-Dec ----------
# Count text links:  111
# G.R. Nos. 131022, 146048 & 146049
# ---------- 1999-Jan ----------
# Count text links:  65
# G.R. No. 128297
# ---------- 1999-Feb ----------
# Count text links:  84
# G.R. No. 127659
# ---------- 1999-Mar ----------
# Count text links:  105
# G.R. No. 123982
# ---------- 1999-Apr ----------
# Count text links:  64
# A.C. No. 4826
# ---------- 1999-May ----------
# Count text links:  67
# G.R. No. 127573
# ---------- 1999-Jun ----------
# Count text links:  90
# G.R. No. 128818
# ---------- 1999-Jul ----------
# Count text links:  111
# G.R. No. 130381
# ---------- 1999-Aug ----------
# Count text links:  99
# G.R. No. 134625
# ---------- 1999-Sep ----------
# Count text links:  140
# G.R. No. 135869
# ---------- 1999-Oct ----------
# Count text links:  115
# G.R. Nos. 129968-69
# ---------- 1999-Nov ----------
# Count text links:  106
# G.R. No. 128743
# ---------- 1999-Dec ----------
# Count text links:  117
# G.R. No. 127639
# ---------- 1998-Jan ----------
# Count text links:  97
# CBD A.C. No. 313
# ---------- 1998-Feb ----------
# Count text links:  50
# G.R. No. 120652
# ---------- 1998-Mar ----------
# Count text links:  86
# G.R. No. 124067
# ---------- 1998-Apr ----------
# Count text links:  59
# G.R. No. 119771
# ---------- 1998-May ----------
# Count text links:  39
# G.R. No. 130570
# ---------- 1998-Jun ----------
# Count text links:  56
# A.M. No. 96-5-163-RTC
# ---------- 1998-Jul ----------
# Count text links:  96
# G.R. No. 108889
# ---------- 1998-Aug ----------
# Count text links:  65
# G.R. No. 102084
# ---------- 1998-Sep ----------
# Count text links:  85
# G.R. No. 116883
# ---------- 1998-Oct ----------
# Count text links:  66
# A.M. No. P-98-1280
# ---------- 1998-Nov ----------
# Count text links:  55
# G.R. No. 131457
# ---------- 1998-Dec ----------
# Count text links:  69
# G.R. No. 124500
# ---------- 1997-Jan ----------
# Count text links:  79
# G.R. No. 113074
# ---------- 1997-Feb ----------
# Count text links:  78
# G.R. No. 112761-65
# ---------- 1997-Mar ----------
# Count text links:  103
# G.R. No. 108395
# ---------- 1997-Apr ----------
# Count text links:  69
# A.M. No. P-94-1070
# ---------- 1997-May ----------
# Count text links:  58
# G.R. No. 103052
# ---------- 1997-Jun ----------
# Count text links:  98
# G.R. No. 97896
# ---------- 1997-Jul ----------
# Count text links:  109
# G.R. No. 121768
# ---------- 1997-Aug ----------
# Count text links:  76
# G.R. No. 109578
# ---------- 1997-Sep ----------
# Count text links:  83
# A.M. No. RTJ-96-1338
# ---------- 1997-Oct ----------
# Count text links:  83
# G.R. No. 121687
# ---------- 1997-Nov ----------
# Count text links:  45
# G.R. Nos. 122980-81
# ---------- 1997-Dec ----------
# Count text links:  54
# G.R. No. 128369
# ---------- 1996-Jan ----------
# Count text links:  58
# G.R. No. 107378
# ---------- 1996-Feb ----------
# Count text links:  84
# G.R. Nos. 115121-25
# ---------- 1996-Mar ----------
# Count text links:  92
# G.R. No. 113194
# ---------- 1996-Apr ----------
# Count text links:  51
# A.M. No. P-95-1133
# ---------- 1996-May ----------
# Count text links:  25
# G.R. No. 24864
# ---------- 1996-Jun ----------
# Count text links:  34
# G.R. No. 117728
# ---------- 1996-Jul ----------
# Count text links:  111
# G.R. No. 109563
# ---------- 1996-Aug ----------
# Count text links:  73
# G.R. No. 111184
# ---------- 1996-Sep ----------
# Count text links:  82
# G.R. No. 105938
# ---------- 1996-Oct ----------
# Count text links:  61
# G.R. No. 112148
# ---------- 1996-Nov ----------
# Count text links:  64
# G.R. No. 106564
# ---------- 1996-Dec ----------
# Count text links:  48
# G.R. No. 118808
